# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys
import os
import glob
import pathlib
import re
import MeCab
import matplotlib
import matplotlib.pyplot as plt
import japanize_matplotlib
import datetime as dt
import pyperclip
# %matplotlib inline 

plt.style.use('ggplot') #プロットスタイルをいい感じにする
pd.set_option('display.max_rows', 25000)
pd.set_option('display.max_columns', 500)

# %%
#parseした結果をDataFrame形式に出力するクラス
class CustomMeCabTagger(MeCab.Tagger):
    
    COLUMNS = ['単語', '品詞', '品詞細分類1', '品詞細分類2', '品詞細分類3', '活用型', '活用形', 'word', 'yomi', '発音']
    
    def parseToDataFrame(self, text: str) -> pd.DataFrame:
        results = []
        for line in self.parse(text).split('\n'):
            if line == 'EOS':
                break
            surface, feature = line.split('\t')
            feature = [None if f == '*' else f for f in feature.split(',')]
            results.append([surface, *feature])
        return pd.DataFrame(results, columns=type(self).COLUMNS)        
tagger = CustomMeCabTagger('mecab-ipadic-neologd')

# %%
#ファイル名の設定
fname = "bad/natsu.txt"
#極性辞書の読み込み
features = ['word', 'p', 'n', 'cate1', 'cate2']
posi_nega_dic = pd.read_csv("stable_posi_nega_dic_ver1.1.1.csv", names=features)

with open(fname,encoding='utf-8') as f:    
    text = f.read()
    
#テキスト全てを形態素解析
morpho_analysed_all = tagger.parseToDataFrame(text)
#解析結果と極性辞書をマージ
morpho_analysed_all = pd.merge(morpho_analysed_all, posi_nega_dic, on = ['word'], how = 'left')
morpho_analysed_all = morpho_analysed_all.reset_index()

#否定語に係る単語の削除(暫定的に前二つに設定)
for i in range(len(morpho_analysed_all)):
    if morpho_analysed_all.loc[i,'word'] == 'ない':
        morpho_analysed_all = morpho_analysed_all.drop(i-1)
        morpho_analysed_all = morpho_analysed_all.drop(i-2)        
        
#辞書とマッチングしたデータフレームの抽出
analysed = morpho_analysed_all.dropna(subset=['p'])
analysed = analysed.reset_index()
#morpho_analysed_all[(morpho_analysed_all['品詞細分類1']== "一般") |(morpho_analysed_all['品詞細分類1']== "自立")]

# %%
#分割数の設定
slice_num = 4

#分割するindexの設定
bins = [0]
for i in range(1,slice_num):
    bins.append(morpho_analysed_all['index'].quantile(1/slice_num* i))
bins = np.rint(bins)
bins = [int(i) for i in bins]
end_index = int(morpho_analysed_all['index'].tail(1))
split_morpho_df = []

#DataFrameの分割
for index in range(len(bins)):
    if index == len(bins)-1:
         a = morpho_analysed_all[bins[index]:end_index]
    else:
         a = morpho_analysed_all[bins[index]:bins[index+1]]
    split_morpho_df.append(a)
    split_morpho_df[index] = split_morpho_df[index].dropna(subset=['p'])
    split_morpho_df[index] = split_morpho_df[index].drop("index", axis=1)


last_df_len = len(split_morpho_df[slice_num-1])
last_emo_len = (split_morpho_df[slice_num-1]['cate1']=="感情").sum()
analysed_all_len = len(analysed)
analysed_all_eve_len = (analysed['cate1']=="イベント").sum()

split_df_p = split_morpho_df[slice_num-1]['p']==1  
split_df_n = split_morpho_df[slice_num-1]['n']==1
last_upper = split_morpho_df[slice_num-1]['cate1']
last_lower = split_morpho_df[slice_num-1]['cate2']
analysed_upper = analysed['cate1']
analysed_lower = analysed['cate2']


emo = "感情"
result_data = ""
emo_low_attribute = ["喜","安","好","厭","悲","恐","怒"]
for i in emo_low_attribute:
    a = str(((last_upper == emo)&(last_lower == i)).sum()/last_df_len)
    result_data += a+"\t"

event = "イベント"
event_low_attribute = ["災", "争い", "死亡", "病気"]
for i in event_low_attribute:
    a = str(((analysed_upper == event)&(analysed_lower == i)).sum()/analysed_all_len)
    result_data += a+"\t"
pyperclip.copy(result_data)
print(fname, "finish")
# Out:
# bad/natsu.txt finish

# %%
split_morpho_df[3][split_morpho_df[3]['cate2']== "悲"]
# Out:
#          単語   品詞  品詞細分類1 品詞細分類2 品詞細分類3       活用型    活用形   word  yomi    発音  \
# 28172     涙   名詞      一般   None   None      None   None      涙   ナミダ   ナミダ
# 29235    絶望   名詞    サ変接続   None   None      None   None     絶望  ゼツボウ  ゼツボー
# 29245     涙   名詞      一般   None   None      None   None      涙   ナミダ   ナミダ
# 29299    泣く   動詞      自立   None   None  五段・カ行イ音便    基本形     泣く    ナク    ナク
# 29443   悲しみ   名詞      一般   None   None      None   None    悲しみ  カナシミ  カナシミ
# 29510  あきらめ   動詞      自立   None   None        一段    連用形  あきらめる  アキラメ  アキラメ
# 29556    沈痛   名詞  形容動詞語幹   None   None      None   None     沈痛  チンツウ  チンツー
# 30011     涙   名詞      一般   None   None      None   None      涙   ナミダ   ナミダ
# 30019    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 30108    泣き   動詞      自立   None   None  五段・カ行イ音便    連用形     泣く    ナキ    ナキ
# 30176    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 30181    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 30294    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 30817    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 30988    泣い   動詞      自立   None   None  五段・カ行イ音便  連用タ接続     泣く    ナイ    ナイ
# 33790    悲し  形容詞      自立   None   None    形容詞・イ段   ガル接続    悲しい   カナシ   カナシ
# 34236   悲しい  形容詞      自立   None   None    形容詞・イ段    基本形    悲しい  カナシイ  カナシイ
# 34348    泣き   動詞      自立   None   None  五段・カ行イ音便    連用形     泣く    ナキ    ナキ
#
#          p    n cate1 cate2
# 28172  0.0  1.0    感情     悲
# 29235  0.0  1.0    感情     悲
# 29245  0.0  1.0    感情     悲
# 29299  0.0  1.0    感情     悲
# 29443  0.0  1.0    感情     悲
# 29510  0.0  1.0    感情     悲
# 29556  0.0  1.0    感情     悲
# 30011  0.0  1.0    感情     悲
# 30019  0.0  1.0    感情     悲
# 30108  0.0  1.0    感情     悲
# 30176  0.0  1.0    感情     悲
# 30181  0.0  1.0    感情     悲
# 30294  0.0  1.0    感情     悲
# 30817  0.0  1.0    感情     悲
# 30988  0.0  1.0    感情     悲
# 33790  0.0  1.0    感情     悲
# 34236  0.0  1.0    感情     悲
# 34348  0.0  1.0    感情     悲

# %%
test = analysed.loc[:,['単語','word', 'p', 'n', 'cate1', 'cate2']]
test = test.rename(columns = {'word':'原型', 'p':'P', 'n':'N', 'cate1':'上位意味カテゴリ', 'cate2':'下位意味カテゴリ'})
test
# Out:
#        単語     原型    P    N 上位意味カテゴリ 下位意味カテゴリ
# 0      慌て    慌てる  0.0  1.0       感情        恐
# 1      死ん     死ぬ  0.0  1.0     イベント       死亡
# 2      地震     地震  0.0  1.0     イベント        災
# 3      楽し    楽しい  1.0  0.0       感情        喜
# 4      笑っ     笑う  1.0  0.0       感情        喜
# 5      失敗     失敗  0.0  1.0       感情        厭
# 6      地震     地震  0.0  1.0     イベント        災
# 7       汚     汚い  0.0  1.0       様相        姿
# 8      苦労     苦労  0.0  1.0       感情        厭
# 9      死ん     死ぬ  0.0  1.0     イベント       死亡
# 10     喜ん     喜ぶ  1.0  0.0       感情        喜
# 11     残念     残念  0.0  1.0       感情        悲
# 12     残念     残念  0.0  1.0       感情        悲
# 13    明るく    明るい  1.0  0.0       様相       性質
# 14     安心     安心  1.0  0.0       感情        安
# 15    薄暗い    薄暗い  0.0  1.0       様相        姿
# 16     好き     好き  1.0  0.0       感情        好
# 17     喜ん     喜ぶ  1.0  0.0       感情        喜
# 18    うれし   うれしい  1.0  0.0       感情        喜
# 19     怒り     怒る  0.0  1.0       感情        怒
# 20   気に入っ   気に入る  1.0  0.0       感情        好
# 21     懇切     懇切  1.0  0.0       感情        好
# 22     才能     才能  1.0  0.0       様相       性質
# 23     残念     残念  0.0  1.0       感情        悲
# 24   うるさい   うるさい  0.0  1.0       感情        厭
# 25     感謝     感謝  1.0  0.0       感情        好
# 26    明るく    明るい  1.0  0.0       様相       性質
# 27     安堵     安堵  1.0  0.0       感情        安
# 28     焦る     焦る  0.0  1.0       感情        恐
# 29     悲鳴     悲鳴  0.0  1.0       感情        恐
# 30     愚か     愚か  0.0  1.0       様相       性質
# 31     恐怖     恐怖  0.0  1.0       感情        恐
# 32     慌て    慌てる  0.0  1.0       感情        恐
# 33     痛い     痛い  0.0  1.0       感情        厭
# 34     困っ     困る  0.0  1.0       感情        厭
# 35     泣き     泣く  0.0  1.0       感情        悲
# 36     失敗     失敗  0.0  1.0       感情        厭
# 37   あきらめ  あきらめる  0.0  1.0       感情        悲
# 38   恐ろしい   恐ろしい  0.0  1.0       感情        恐
# 39   だきつい   だきつく  1.0  0.0       感情        好
# 40     感謝     感謝  1.0  0.0       感情        好
# 41     残念     残念  0.0  1.0       感情        悲
# 42     焦っ     焦る  0.0  1.0       感情        恐
# 43     脅迫     脅迫  0.0  1.0     イベント       争い
# 44     憎悪     憎悪  0.0  1.0       感情        厭
# 45   あきらめ  あきらめる  0.0  1.0       感情        悲
# 46     失敗     失敗  0.0  1.0       感情        厭
# 47     痛い     痛い  0.0  1.0       感情        厭
# 48    わめい    わめく  0.0  1.0       感情        恐
# 49     盗も     盗む  0.0  1.0     イベント        災
# 50     愚か     愚か  0.0  1.0       様相       性質
# 51     怪我     怪我  0.0  1.0     イベント       争い
# 52    微笑ん    微笑む  1.0  0.0       感情        喜
# 53     死ん     死ぬ  0.0  1.0     イベント       死亡
# 54    つかれ   つかれる  0.0  1.0       感情        厭
# 55     好き     好き  1.0  0.0       感情        好
# 56     期待     期待  1.0  0.0       様相       期待
# 57     喜ん     喜ぶ  1.0  0.0       感情        喜
# 58   嬉しかっ    嬉しい  1.0  0.0       感情        喜
# 59   思いやり   思いやり  1.0  0.0       感情        好
# 60     事件     事件  0.0  1.0     イベント        災
# 61     無視     無視  0.0  1.0     イベント       争い
# 62     死ん     死ぬ  0.0  1.0     イベント       死亡
# 63     無視     無視  0.0  1.0     イベント       争い
# 64     即死     即死  0.0  1.0     イベント       死亡
# 65     死ぬ     死ぬ  0.0  1.0     イベント       死亡
# 66     笑っ     笑う  1.0  0.0       感情        喜
# 67    悲しい    悲しい  0.0  1.0       感情        悲
# 68   息苦しく   息苦しい  0.0  1.0       感情        厭
# 69     怒り     怒り  0.0  1.0       感情        怒
# 70    悲しみ    悲しみ  0.0  1.0       感情        悲
# 71     後悔     後悔  0.0  1.0       感情        厭
# 72    微笑む    微笑む  1.0  0.0       感情        喜
# 73     脅迫     脅迫  0.0  1.0     イベント       争い
# 74     残念     残念  0.0  1.0       感情        悲
# 75     焦っ     焦る  0.0  1.0       感情        恐
# 76   力尽きる   力尽きる  0.0  1.0     イベント       病気
# 77     痛い     痛い  0.0  1.0       感情        厭
# 78     警戒     警戒  0.0  1.0       感情        恐
# 79     安堵     安堵  1.0  0.0       感情        安
# 80     才能     才能  1.0  0.0       様相       性質
# 81     憤慨     憤慨  0.0  1.0       感情        怒
# 82     笑み     笑み  1.0  0.0       感情        喜
# 83     事故     事故  0.0  1.0     イベント        災
# 84     罵っ     罵る  0.0  1.0     イベント       争い
# 85     罵る     罵る  0.0  1.0     イベント       争い
# 86     綺麗     綺麗  1.0  0.0       様相        姿
# 87     困惑     困惑  0.0  1.0       感情        恐
# 88     嬉し    嬉しい  1.0  0.0       感情        喜
# 89     人気     人気  1.0  0.0       様相       性質
# 90     人気     人気  1.0  0.0       様相       性質
# 91     感心     感心  1.0  0.0       感情        喜
# 92     非難     非難  0.0  1.0     イベント       争い
# 93     怒っ     怒る  0.0  1.0       感情        怒
# 94     嫌い     嫌い  0.0  1.0       感情        厭
# 95     嫌い     嫌う  0.0  1.0       感情        厭
# 96     死ぬ     死ぬ  0.0  1.0     イベント       死亡
# 97    美しい    美しい  1.0  0.0       様相        姿
# 98      臆      臆  0.0  1.0       感情        恐
# 99     笑み     笑み  1.0  0.0       感情        喜
# 100    人気     人気  1.0  0.0       様相       性質
# 101    人気     人気  1.0  0.0       様相       性質
# 102   明るく    明るい  1.0  0.0       様相       性質
# 103    嬉し    嬉しい  1.0  0.0       感情        喜
# 104    感動     感動  1.0  0.0       感情        喜
# 105  気に入っ   気に入る  1.0  0.0       感情        好
# 106    感謝     感謝  1.0  0.0       感情        好
# 107    怒り     怒り  0.0  1.0       感情        怒
# 108    好き     好き  1.0  0.0       感情        好
# 109    緊張     緊張  0.0  1.0       感情        厭
# 110  美しかっ    美しい  1.0  0.0       様相        姿
# 111   美しい    美しい  1.0  0.0       様相        姿
# 112    笑み     笑み  1.0  0.0       感情        喜
# 113    笑み     笑み  1.0  0.0       感情        喜
# 114    笑み     笑み  1.0  0.0       感情        喜
# 115    笑み     笑み  1.0  0.0       感情        喜

# %%
analysed[analysed['cate2']== "災"]
# Out:
#     level_0  index  単語  品詞 品詞細分類1 品詞細分類2 品詞細分類3   活用型   活用形 word  yomi    発音  \
# 6       921    921  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 15     2870   2870  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 22     3435   3435  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 23     3467   3467  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 24     3484   3484  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 25     3493   3493  被害  名詞     一般   None   None  None  None   被害   ヒガイ   ヒガイ
# 27     3741   3741  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 34     6771   6771  被害  名詞     一般   None   None  None  None   被害   ヒガイ   ヒガイ
# 50    10544  10544  犯行  名詞     一般   None   None  None  None   犯行  ハンコウ  ハンコー
# 51    10679  10679  被害  名詞     一般   None   None  None  None   被害   ヒガイ   ヒガイ
# 52    10694  10694  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
# 63    11110  11110  事件  名詞     一般   None   None  None  None   事件   ジケン   ジケン
#
#       p    n cate1 cate2
# 6   0.0  1.0  イベント     災
# 15  0.0  1.0  イベント     災
# 22  0.0  1.0  イベント     災
# 23  0.0  1.0  イベント     災
# 24  0.0  1.0  イベント     災
# 25  0.0  1.0  イベント     災
# 27  0.0  1.0  イベント     災
# 34  0.0  1.0  イベント     災
# 50  0.0  1.0  イベント     災
# 51  0.0  1.0  イベント     災
# 52  0.0  1.0  イベント     災
# 63  0.0  1.0  イベント     災

# %%
posi_nega_dic.sample(n = 10).rename(columns={"word":"単語", "p":"P","n":"N","cate1":"上位意味カテゴリ", "cate2":"下位意味カテゴリ"})
# Out:
#         単語  P  N 上位意味カテゴリ 下位意味カテゴリ
# 1181  ほほえむ  1  0       感情        好
# 67     気疲れ  0  1       感情        厭
# 182     悲観  0  1       感情        悲
# 18      殴打  0  1     イベント       争い
# 1276    争議  0  1     イベント       争い
# 404    絶望感  0  1       感情        悲
# 611     傷害  0  1     イベント       病気
# 13      苦手  0  1       感情        厭
# 961   うるうる  0  1       感情        悲
# 809     疎む  0  1       感情        厭

# %%
posi_nega_dic.groupby('cate2').sum()
# Out:
#          p    n
# cate2
# 争い       0  187
# 厭        0  158
# 喜       84    0
# 好      167    0
# 姿       71   22
# 安       19    0
# 怒        0   50
# 性質      46   36
# 恐        0   79
# 悲        0  111
# 死亡       0   63
# 災        0   66
# 病気       0  157
# 関係       2    3
